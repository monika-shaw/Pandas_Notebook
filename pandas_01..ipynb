# %%
import pandas as pd
df = pd.read_csv('c:\\datas\\weathers.csv')
df
# Out:
#            CST  Temperature  DewPoint  Humidity  Sea Level Pressure  \
# 0   01-01-2021           38        23        52               30.30
# 1   01-02-2021           36        18        46               30.02
# 2   02-02-2021           40        21        47               29.86
# 3   03-02-2021           25         9        44               30.05
# 4   04-02-2021           20        -3        41               30.57
# 5   05-02-2021           33         4        35               30.50
# 6   06-02-2021           39        11        33               30.28
# 7   07-02-2021           39        29        64               30.20
# 8   08-02-2021           44        38        77               30.16
# 9   09-02-2021           50        46        71               29.59
# 10  10-02-2021           33         8        37               29.92
# 11  11-02-2021           35        15        53               29.85
# 12  12-02-2021           26         4        42               29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['CST'][df['Events']=='Rain']
# Out:
# 8    08-02-2021
# 9    09-02-2021
# Name: CST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.285714285714286

# %%
df.fillna(0,inplace=True)

# %%
df['WindSpeedMPH'].mean()
# Out:
# 5.5

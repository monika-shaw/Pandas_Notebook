# %%
import pandas as pd
df = pd.read_csv("c:\\datas\\group.csv")
df
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2020  new york         32.0        6.0    Rain
# 1   01-02-2020  new york         36.0        7.0   Sunny
# 2   02-02-2020  new york         28.0       12.0    Snow
# 3   03-02-2020  new york         33.0        7.0   Sunny
# 4   04-02-2020    mumbai         90.0        5.0   Sunny
# 5   05-02-2020    mumbai          8.0       12.0     Fog
# 6   06-02-2020    mumbai         87.0       15.0     Fog
# 7   07-02-2020    mumbai         92.0        5.0    Rain
# 8   08-02-2020     paris         45.0       20.0   Sunny
# 9   09-02-2020     paris         50.0       13.0  Cloudy
# 10  10-02-2020     paris         54.0        8.0  Cloudy
# 11  11-02-2020     paris         42.0       10.0  Cloudy
# 12         NaN       NaN          NaN        NaN     NaN

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event
# 4  04-02-2020  mumbai         90.0        5.0  Sunny
# 5  05-02-2020  mumbai          8.0       12.0    Fog
# 6  06-02-2020  mumbai         87.0       15.0    Fog
# 7  07-02-2020  mumbai         92.0        5.0   Rain
# new york
#           day      city  temperature  windspeed  event
# 0  01-01-2020  new york         32.0        6.0   Rain
# 1  01-02-2020  new york         36.0        7.0  Sunny
# 2  02-02-2020  new york         28.0       12.0   Snow
# 3  03-02-2020  new york         33.0        7.0  Sunny
# paris
#            day   city  temperature  windspeed   event
# 8   08-02-2020  paris         45.0       20.0   Sunny
# 9   09-02-2020  paris         50.0       13.0  Cloudy
# 10  10-02-2020  paris         54.0        8.0  Cloudy
# 11  11-02-2020  paris         42.0       10.0  Cloudy

# %%
g.get_group('mumbai')
# Out:
#           day    city  temperature  windspeed  event
# 4  04-02-2020  mumbai         90.0        5.0  Sunny
# 5  05-02-2020  mumbai          8.0       12.0    Fog
# 6  06-02-2020  mumbai         87.0       15.0    Fog
# 7  07-02-2020  mumbai         92.0        5.0   Rain

# %%
g.max()
# Out:
#                  day  temperature  windspeed  event
# city
# mumbai    07-02-2020         92.0       15.0  Sunny
# new york  03-02-2020         36.0       12.0  Sunny
# paris     11-02-2020         54.0       20.0  Sunny

# %%
g.min()
# Out:
#                  day  temperature  windspeed   event
# city
# mumbai    04-02-2020          8.0        5.0     Fog
# new york  01-01-2020         28.0        6.0    Rain
# paris     08-02-2020         42.0        8.0  Cloudy

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          69.25       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                    \
#                count   mean        std   min    25%   50%    75%   max
# city
# mumbai           4.0  69.25  40.885001   8.0  67.25  88.5  90.50  92.0
# new york         4.0  32.25   3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75   5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

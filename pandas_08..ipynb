# %%
import pandas as pd

india_weather = pd.DataFrame({
    'city': ['mumbai','delhi','banglore'],
    'temperature' : [22,65,70],
    'himidity': [80,60,78]
    
})
india_weather
# Out:
#        city  temperature  himidity
# 0    mumbai           22        80
# 1     delhi           65        60
# 2  banglore           70        78

# %%
us_weather = pd.DataFrame({
     'city': ['new york','chicago','canada'],
    'temperature' : [21,14,35],
    'himidity': [65,65,75]
})
us_weather
# Out:
#        city  temperature  himidity
# 0  new york           21        65
# 1   chicago           14        65
# 2    canada           35        75

# %%
df=pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  himidity
# 0    mumbai           22        80
# 1     delhi           65        60
# 2  banglore           70        78
# 0  new york           21        65
# 1   chicago           14        65
# 2    canada           35        75

# %%
df=pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#        city  temperature  himidity
# 0    mumbai           22        80
# 1     delhi           65        60
# 2  banglore           70        78
# 3  new york           21        65
# 4   chicago           14        65
# 5    canada           35        75

# %%
df=pd.concat([india_weather, us_weather],  keys=["india","us"])
df
# Out:
#              city  temperature  himidity
# india 0    mumbai           22        80
#       1     delhi           65        60
#       2  banglore           70        78
# us    0  new york           21        65
#       1   chicago           14        65
#       2    canada           35        75

# %%
df.loc["india"]
# Out:
#        city  temperature  himidity
# 0    mumbai           22        80
# 1     delhi           65        60
# 2  banglore           70        78

# %%
temperature_df =pd.DataFrame({
    'city': ['mumbai','delhi','banglore'],
    'temperature' : [22,65,70],
    
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           22
# 1     delhi           65
# 2  banglore           70

# %%
wind_df =pd.DataFrame({
    'city': ['mumbai','delhi','banglore'],
    'windspeed' : [22,65,70],
    
})
wind_df
# Out:
#        city  windspeed
# 0    mumbai         22
# 1     delhi         65
# 2  banglore         70

# %%
df=pd.concat([temperature_df,wind_df])
df
# Out:
#        city  temperature  windspeed
# 0    mumbai         22.0        NaN
# 1     delhi         65.0        NaN
# 2  banglore         70.0        NaN
# 0    mumbai          NaN       22.0
# 1     delhi          NaN       65.0
# 2  banglore          NaN       70.0

# %%
df=pd.concat([temperature_df,wind_df], axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           22    mumbai         22
# 1     delhi           65     delhi         65
# 2  banglore           70  banglore         70

# %%
temperature_df =pd.DataFrame({
    'city': ['mumbai','delhi','banglore'],
    'temperature' : [22,65,70],
    
})
temperature_df
# Out:
#        city  temperature
# 0    mumbai           22
# 1     delhi           65
# 2  banglore           70

# %%
wind_df =pd.DataFrame({
    'city': ['delhi','banglore'],
    'windspeed' : [22,6],
    
})
wind_df
# Out:
#        city  windspeed
# 0     delhi         22
# 1  banglore          6

# %%
df=pd.concat([temperature_df,wind_df], axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           22     delhi       22.0
# 1     delhi           65  banglore        6.0
# 2  banglore           70       NaN        NaN

# %%
temperature_df =pd.DataFrame({
    'city': ['mumbai','delhi','banglore'],
    'temperature' : [22,65,70],
    
},index=[0,1,2])
temperature_df
# Out:
#        city  temperature
# 0    mumbai           22
# 1     delhi           65
# 2  banglore           70

# %%
wind_df =pd.DataFrame({
    'city': ['delhi','banglore'],
    'windspeed' : [22,6],
    
},index=[1,2])
wind_df
# Out:
#        city  windspeed
# 1     delhi         22
# 2  banglore          6

# %%
df=pd.concat([temperature_df,wind_df], axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           22       NaN        NaN
# 1     delhi           65     delhi       22.0
# 2  banglore           70  banglore        6.0

# %%
temperature_df
# Out:
#        city  temperature
# 0    mumbai           22
# 1     delhi           65
# 2  banglore           70

# %%
s = pd.Series(['Humid','Dry','Rain'],name='event')
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df=pd.concat([temperature_df,s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           22  Humid
# 1     delhi           65    Dry
# 2  banglore           70   Rain
